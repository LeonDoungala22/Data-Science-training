# %% [markdown]
# # Enssemble learning and methods

# %% [markdown]
# En machine learning, la méthode ensembliste consiste à utiliser plusieurs algorithmes d'apprentissage automatique, en les mettant en commun pour obtenir des prédictions de meilleure qualité

# %% [markdown]
# [Sklearn doc](https://scikit-learn.org/stable/modules/ensemble.html)

# %% [markdown]
# [French doc](https://www.journaldunet.fr/web-tech/guide-de-l-intelligence-artificielle/1501883-methode-ensembliste-ensemble-learning/)

# %% [markdown]
# [Italiano doc : Ottima spiegazione](https://www.andreaminini.com/ai/machine-learning/ensemble-learning)

# %% [markdown]
# ![ensemble-methods.png](attachment:ensemble-methods.png)

# %% [markdown]
# ### Comment fonctionne le machine learning ensembliste ?

# %% [markdown]
# Il existe deux grandes méthodes ensemblistes, la séquentielle et la parallèle. Avec la méthode d'ensemble learning séquentielle, les modèles sont entraînés à la suite, ce qui leur permet d’apprendre au fur et à mesure de leurs erreurs. Avec la méthode ensembliste parallèle, les modèles sont entraînés en simultané. Chaque modèle est entraîné sur une sous-échantillon de l'ensemble de données d'apprentissage. Pour déterminer le résultat final, on procède par un vote des résultats de chaque modèle pour une classification, ou par une moyenne pour une régression.

# %% [markdown]
# ### Hard voting and soft voting

# %% [markdown]
# ![0_ikXrXKWDoTRi18Tm.png](attachment:0_ikXrXKWDoTRi18Tm.png)

# %% [markdown]
# ### Boosting vs bagging vs forêt aléatoire : quelle différence entre ces algorithmes ensemblistes ?

# %% [markdown]
# Pour combiner toutes les informations portées par chaque modèle, il convient de diminuer leur variance afin de réduire leur sensibilité aux données ( Revient à reduire/minimiser le coeficient de determination R^2), et pour y parvenir il est possible d’employer diverses techniques en machine learning :

# %% [markdown]
# ![R-squared-formula-function-of-SSE-and-SST.jpg](attachment:R-squared-formula-function-of-SSE-and-SST.jpg)

# %% [markdown]
# #### - Le bagging (une méthode ensembliste parallèle)

# %% [markdown]
# Aussi appelé bootstrap aggregating, consiste à sous-échantillonner les données, en créant un data set pour chaque modèle. Pour déterminer le résultat final, on procède par un vote des résultats de chaque modèle pour une classification, ou par une moyenne pour une régression.

# %% [markdown]
# #### - Le boosting (une méthode ensembliste séquentielle)

# %% [markdown]
#  Combine les modèles classifieurs en les pondérant à chaque nouvelle prédiction, de façon à ce que les modèles ayant prédit correctement aient un poids plus important que les modèles incorrects.

# %% [markdown]
# ![81232a78-2e99-4ccc-ba8e-8cd873625fdf_2%20%281%29.jpg](attachment:81232a78-2e99-4ccc-ba8e-8cd873625fdf_2%20%281%29.jpg)

# %% [markdown]
# #### - La forêt aléatoire ( Random forest)

# %% [markdown]
# Est une amélioration du bagging, qui est associé au concept de sous-espace aléatoire, et qui s’attache à créer de multiples arbres de décision, avec des modèles entraînés sur des sous-ensembles de données légèrement différents. Vu que les échantillons sont créés de manière aléatoire, la corrélation entre les arbres est réduite, et on obtient in fine à un meilleur résultat. Cette méthode est de nos jours très utilisée par les data scientists.

# %% [markdown]
# ![2-Figure2-1.png](attachment:2-Figure2-1.png)

# %% [markdown]
# ![Immagine%202022-09-29%20144050.png](attachment:Immagine%202022-09-29%20144050.png)

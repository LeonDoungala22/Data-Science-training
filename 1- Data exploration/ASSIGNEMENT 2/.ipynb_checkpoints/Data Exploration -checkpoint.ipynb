# %%
# [Data Science Course] Data Exploration: assignment #2 - How to handle missing values?

# %% [markdown]
# ### Assignement Guide

# %%
#Assignement Guide
import Utilities as Util

file_Description_name = "Assignment _GUIDE_handle_missing_values.txt"
Util.read_txt(file_Description_name)
# Out:
# In questa settimana direi di concentrarci su come gestire i valori mancanti in un dataset.
#
# A seguito di quanto mi hai presentato venerdi scorso, direi che possiamo migliorare come rimpiazzare i valori mancanti in un caso reale.
#
#
#
# La tua soluzione Ã¨ quella piÃ¹ semplice: rimuovere tutte le righe che hanno almeno un valore mancante in qualsiasi colonna (nel tuo caso, un sotto-insieme di colonne).
#
# Questa idea perÃ² non Ã¨ applicabile in uno scenario reale, questo perchÃ© andremmo a eliminare potenzialmente tante righe del nostro dataset e anche perchÃ© nelle analisi successive andremmo a rappresentare un dataset differente da quello originale, da quello reale.
#
#
#
# Per questo motivo, nel corso del tempo si sono pensate a strade alternative:
#
# - Sostituire un valore mancante tramite media (se Ã¨ una variabile numerica)
# - Sostituire un valore mancante tramite moda (se Ã¨ una variabile categorica)
# - Sostituire un valore mancante tramite un valore di default, non ammissibile come valore della colonna presa in considerazione, e.g. "MISSING"
# - Sostituire un valore mancante tramite delle regole basandosi sui valori di altre colonne
# - Sostituire un valore mancante di una colonna tramite un algoritmo statistico/basato su ML, e.g. KNN
#
#
# Ovviamente, ogni tecnica ha i propri vantaggi e svantaggi, come per esempio applicare algoritmi ML-based richiedono piÃ¹ tempo e possono introdurre degli errori nel dataset.
#
#
#
# Capire quale tecnica applicare in ogni caso richiede esperienza nel trattare valori mancanti, ma soprattutto esperienza nel caso dâ€™uso.
# Per esempio, se so che una colonna X non Ã¨ valorizzata allora deve essere sostituita con un valore di default allora applicherÃ² questa tecnica.
#
# Un mio consiglio Ã¨ partire dalla tecnica piÃ¹ semplice, vedere i risultati ottenuti e se non contenti provare a complicare la soluzione.
#
#
#
# Ecco qui alcuni link che ti consiglio di guardare per acquisire maggiore conoscenza sia a livello teorico che a livello pratico:
#
# - 6.4. Imputation of missing values â€” scikit-learn 1.1.1 documentation : https://scikit-learn.org/stable/modules/impute.html
# - 6 Different Ways to Compensate for Missing Values In a Dataset (Data Imputation with examples) | by Will Badr | Towards Data Science : https://towardsdatascience.com/6-different-ways-to-compensate-for-missing-values-data-imputation-with-examples-6022d9ca0779
# - 7 Ways to Handle Missing Values in Machine Learning | by Satyam Kumar | Towards Data Science : https://towardsdatascience.com/7-ways-to-handle-missing-values-in-machine-learning-1a6326adf79e
# - How to Deal with Missing Values in Your Dataset - KDnuggets : https://www.kdnuggets.com/2020/06/missing-values-dataset.html
# - 5 Ways To Handle Missing Values In Machine Learning Datasets (analyticsindiamag.com):https://analyticsindiamag.com/5-ways-handle-missing-values-machine-learning-datasets/
# - Handling missing value | Data cleaning | Analytics Vidhya (medium.com): https://medium.com/analytics-vidhya/the-why-and-how-to-handle-missing-values-46ab8c1b9034
# - A Complete Guide to Dealing with Missing values in Python (analyticsvidhya.com) : https://www.analyticsvidhya.com/blog/2021/10/a-complete-guide-to-dealing-with-missing-values-in-python/
# - How to Handle Missing Data with Python (machinelearningmastery.com): https://machinelearningmastery.com/handle-missing-data-python/#:~:text=In%20Python%2C%20specifically%20Pandas%2C%20NumPy%20and%20Scikit-Learn%2C%20we,subset%20of%20the%20columns%20we%20are%20interested%20in.
#
#
# L'obiettivo di questa settimana Ã¨:
#
# - Capire a livello teorico il problema dei missing values
# - Quali possibilitÃ  possono essere messe in campo per gestire missing values
# - Provare le diverse tecniche su un dataset a piacere (puoi usare quello usato nellâ€™assignment #1)
# - Trarre delle conclusioni e capire quali tecniche Ã¨ meglio applicare in quale situazione

# %% [markdown]
# ## ACTIVITY 1 : Health_AnimalBites

# %%
#Take a look to the dataset . Using personalize module 

file_Description_name = "Dataset/dataset_description.txt"
Util.read_txt(file_Description_name)
# Out:
# Context:
# ********
# In the United States, animal bites are often reported to law enforcement (such as animal control). The main concern with an animal bite is that the animal may be rabid. This dataset includes information on over 9,000 animal bites which occurred near Louisville, Kentucky from 1985 to 2017 and includes information on whether the animal was quarantined after the bite occurred and whether that animal was rabid.
#
# Content:
# ********
#
# Attributes of animal bite incidents reported to and investigated by Louisville Metro Department of Public Health and Wellness. Personal/identifying data has been removed. This dataset is a single .csv with the following fields.
#
# - bite_date: The date the bite occurred
# - SpeciesIDDesc: The species of animal that did the biting
# - BreedIDDesc: Breed (if known)
# - GenderIDDesc: Gender (of the animal)
# - color: color of the animal
# - vaccination_yrs: how many years had passed since the last vaccination
# - vaccination_date: the date of the last vaccination
# - victim_zip: the zipcode of the victim
# - AdvIssuedYNDesc: whether advice was issued
# - WhereBittenIDDesc: Where on the body the victim was bitten
# - quarantine_date: whether the animal was quarantined
# - DispositionIDDesc: whether the animal was released from quarantine
# - headsentdate: the date the animalâ€™s head was sent to the lab
# - release_date: the date the animal was released
# - ResultsIDDesc: results from lab tests (for rabies)
#
# Acknowledgements:
# *****************
#
# Attributes of animal bite incidents reported to and investigated by Louisville Metro Department of Public Health and Wellness. This data is in the public domain.
#
# Inspiration:
# ************
#
# . Which animals are most likely to bite humans?
# . Are some dog breeds more likely to bite?
# . What factors are most strongly associated with a positive rabies ID?

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
import missingno as msno
from dython.nominal import identify_nominal_columns
from dython.nominal import associations

# %%
#Read 
file_path = "Dataset/Health_AnimalBites.csv"
Data = pd.read_csv(file_path)

#Read the first 5 rows of the dataset
Data.head(5)
# Out:
#              bite_date SpeciesIDDesc BreedIDDesc GenderIDDesc       color  \
# 0  1985-05-05 00:00:00           DOG         NaN       FEMALE  LIG. BROWN
# 1  1986-02-12 00:00:00           DOG         NaN      UNKNOWN   BRO & BLA
# 2  1987-05-07 00:00:00           DOG         NaN      UNKNOWN         NaN
# 3  1988-10-02 00:00:00           DOG         NaN         MALE   BLA & BRO
# 4  1989-08-29 00:00:00           DOG         NaN       FEMALE     BLK-WHT
#
#    vaccination_yrs     vaccination_date victim_zip AdvIssuedYNDesc  \
# 0              1.0  1985-06-20 00:00:00      40229              NO
# 1              NaN                  NaN      40218              NO
# 2              NaN                  NaN      40219              NO
# 3              NaN                  NaN        NaN              NO
# 4              NaN                  NaN        NaN              NO
#
#   WhereBittenIDDesc      quarantine_date DispositionIDDesc head_sent_date  \
# 0              BODY  1985-05-05 00:00:00           UNKNOWN            NaN
# 1              BODY  1986-02-12 00:00:00           UNKNOWN            NaN
# 2              BODY  1990-05-07 00:00:00           UNKNOWN            NaN
# 3              BODY  1990-10-02 00:00:00           UNKNOWN            NaN
# 4              BODY                  NaN           UNKNOWN            NaN
#
#   release_date ResultsIDDesc
# 0          NaN       UNKNOWN
# 1          NaN       UNKNOWN
# 2          NaN       UNKNOWN
# 3          NaN       UNKNOWN
# 4          NaN       UNKNOWN

# %%
#missinggno is used to visualized missing values
msno.matrix(Data)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The trouble that we immediately see is that the values in this dataset are highly sparse: there seem to be quite a few NaN values. We can use missingno to see just how sparse.

# %%
#Drop duplicate rows
Data = Data.drop_duplicates()
Data.shape
# Out:
# (8954, 15)

# %%
#data description including object data type
Data.describe(include ='object')
# Out:
#                   bite_date SpeciesIDDesc BreedIDDesc GenderIDDesc  color  \
# count                  8659          8847        3747         6468   6414
# unique                 2702             9         101            3    712
# top     2017-08-15 00:00:00           DOG    PIT BULL         MALE  BLACK
# freq                     13          7003        1095         3826    670
#
#            vaccination_date victim_zip AdvIssuedYNDesc WhereBittenIDDesc  \
# count                  4110       7143            2560              8361
# unique                 2107        233               2                 3
# top     2015-10-01 00:00:00      40272              NO              BODY
# freq                      8        376            1912              6190
#
#             quarantine_date DispositionIDDesc       head_sent_date  \
# count                  2018              1535                  393
# unique                  602                 4                  325
# top     2010-04-05 00:00:00          RELEASED  2010-05-21 00:00:00
# freq                     18               912                    4
#
#                release_date ResultsIDDesc
# count                  1442          1541
# unique                  582             3
# top     2016-07-05 00:00:00       UNKNOWN
# freq                     13          1240

# %%
#Dataset info
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8954 entries, 0 to 9002
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   bite_date          8659 non-null   object
#  1   SpeciesIDDesc      8847 non-null   object
#  2   BreedIDDesc        3747 non-null   object
#  3   GenderIDDesc       6468 non-null   object
#  4   color              6414 non-null   object
#  5   vaccination_yrs    3733 non-null   float64
#  6   vaccination_date   4110 non-null   object
#  7   victim_zip         7143 non-null   object
#  8   AdvIssuedYNDesc    2560 non-null   object
#  9   WhereBittenIDDesc  8361 non-null   object
#  10  quarantine_date    2018 non-null   object
#  11  DispositionIDDesc  1535 non-null   object
#  12  head_sent_date     393 non-null    object
#  13  release_date       1442 non-null   object
#  14  ResultsIDDesc      1541 non-null   object
# dtypes: float64(1), object(14)
# memory usage: 1.1+ MB

# %%
def count_na_rows_withPie():
    print(Data.isnull().sum().sort_values)
    Data.isnull().sum().plot.barh(figsize=(20, 15))
    print("\nData shape:",Data.shape)
    
def count_na_rows():
    print(Data.isnull().sum())
    print("\nData shape:",Data.shape)

# %%
count_na_rows_withPie()
# Out:
# <bound method Series.sort_values of bite_date             295
# SpeciesIDDesc         107
# BreedIDDesc          5207
# GenderIDDesc         2486
# color                2540
# vaccination_yrs      5221
# vaccination_date     4844
# victim_zip           1811
# AdvIssuedYNDesc      6394
# WhereBittenIDDesc     593
# quarantine_date      6936
# DispositionIDDesc    7419
# head_sent_date       8561
# release_date         7512
# ResultsIDDesc        7413
# dtype: int64>
#
# Data shape: (8954, 15)

# %%
Data['vaccination_date']= pd.to_datetime(Data['vaccination_date'])
Data['quarantine_date'] = pd.to_datetime(Data['quarantine_date'])
Data['release_date'] = pd.to_datetime(Data['release_date']) #TBD

# %%
Data['release_date']#.dt.year # TO LEARN
# Out:
# 0      NaT
# 1      NaT
# 2      NaT
# 3      NaT
# 4      NaT
#         ..
# 8998   NaT
# 8999   NaT
# 9000   NaT
# 9001   NaT
# 9002   NaT
# Name: release_date, Length: 8954, dtype: datetime64[ns]

# %%
#Data types analisi info
print("- All Data types :\n\n",Data.dtypes.info)
print("\n\n- Object type :",Data.dtypes[Data.dtypes == "object"].value_counts())
print("- Float type :",Data.dtypes[Data.dtypes == "float"].value_counts())
print("\n\n- Order types :",Data.dtypes[Data.dtypes != "object"].value_counts())

Data.dtypes.value_counts().plot.pie(figsize=(15, 12))
# Out:
# - All Data types :
#
#  <bound method Series.info of bite_date                    object
# SpeciesIDDesc                object
# BreedIDDesc                  object
# GenderIDDesc                 object
# color                        object
# vaccination_yrs             float64
# vaccination_date     datetime64[ns]
# victim_zip                   object
# AdvIssuedYNDesc              object
# WhereBittenIDDesc            object
# quarantine_date      datetime64[ns]
# DispositionIDDesc            object
# head_sent_date               object
# release_date         datetime64[ns]
# ResultsIDDesc                object
# dtype: object>
#
#
# - Object type : object    11
# dtype: int64
# - Float type : float64    1
# dtype: int64
#
#
# - Order types : datetime64[ns]    3
# float64           1
# dtype: int64
# <AxesSubplot:ylabel='None'>

# %%
#Categorical variables indexs and description
categorical_val = Data.dtypes[Data.dtypes == "object"].index

print(categorical_val)
Data[categorical_val].describe()
# Out:
# Index(['bite_date', 'SpeciesIDDesc', 'BreedIDDesc', 'GenderIDDesc', 'color',
#        'victim_zip', 'AdvIssuedYNDesc', 'WhereBittenIDDesc',
#        'DispositionIDDesc', 'head_sent_date', 'ResultsIDDesc'],
#       dtype='object')
#                   bite_date SpeciesIDDesc BreedIDDesc GenderIDDesc  color  \
# count                  8659          8847        3747         6468   6414
# unique                 2702             9         101            3    712
# top     2017-08-15 00:00:00           DOG    PIT BULL         MALE  BLACK
# freq                     13          7003        1095         3826    670
#
#        victim_zip AdvIssuedYNDesc WhereBittenIDDesc DispositionIDDesc  \
# count        7143            2560              8361              1535
# unique        233               2                 3                 4
# top         40272              NO              BODY          RELEASED
# freq          376            1912              6190               912
#
#              head_sent_date ResultsIDDesc
# count                   393          1541
# unique                  325             3
# top     2010-05-21 00:00:00       UNKNOWN
# freq                      4          1240

# %%
#Numerical variables and description
Numerical_val = Data.dtypes[Data.dtypes != "object"].index

print(Numerical_val)
Data[Numerical_val].describe()
# Out:
# Index(['vaccination_yrs', 'vaccination_date', 'quarantine_date',
#        'release_date'],
#       dtype='object')
#        vaccination_yrs
# count      3733.000000
# mean          1.452719
# std           0.848823
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max          11.000000

# %% [markdown]
# ### Handle missing values

# %% [markdown]
# Possibles solutions :
#
# - Replacing a missing value via mean (if it is a numeric variable)
# - Replace a missing value via mode (if it is a categorical variable)
# - Replace a missing value by a default value, which is not admissible as a value for the column under consideration, e.g. "MISSING".
# - Replace a missing value by rules based on the values of other columns
# - Replace a missing column value by a statistical/ML-based algorithm, e.g. KNN

# %%
#Count missing values by rows
count_na_rows()
# Out:
# bite_date             295
# SpeciesIDDesc         107
# BreedIDDesc          5207
# GenderIDDesc         2486
# color                2540
# vaccination_yrs      5221
# vaccination_date     4844
# victim_zip           1811
# AdvIssuedYNDesc      6394
# WhereBittenIDDesc     593
# quarantine_date      6936
# DispositionIDDesc    7419
# head_sent_date       8561
# release_date         7512
# ResultsIDDesc        7413
# dtype: int64
#
# Data shape: (8954, 15)

# %%
#Missig values and radio 
missing_values = Data.isnull().sum()/len(Data) # missing value ratio .  (Idealy near to 0 )
missing_values.sort_values(inplace=True)  # sorting

round(missing_values,2)
# Out:
# SpeciesIDDesc        0.01
# bite_date            0.03
# WhereBittenIDDesc    0.07
# victim_zip           0.20
# GenderIDDesc         0.28
# color                0.28
# vaccination_date     0.54
# BreedIDDesc          0.58
# vaccination_yrs      0.58
# AdvIssuedYNDesc      0.71
# quarantine_date      0.77
# ResultsIDDesc        0.83
# DispositionIDDesc    0.83
# release_date         0.84
# head_sent_date       0.96
# dtype: float64

# %%
# Now lets create a pandas dataframe of above result , to manipulate our dataset missing values values:
missing_values = (pd.DataFrame(missing_values))
missing_values.columns = ['count'] 
missing_values.index.names = ['Name']
round(missing_values,2)
# Out:
#                    count
# Name
# SpeciesIDDesc       0.01
# bite_date           0.03
# WhereBittenIDDesc   0.07
# victim_zip          0.20
# GenderIDDesc        0.28
# color               0.28
# vaccination_date    0.54
# BreedIDDesc         0.58
# vaccination_yrs     0.58
# AdvIssuedYNDesc     0.71
# quarantine_date     0.77
# ResultsIDDesc       0.83
# DispositionIDDesc   0.83
# release_date        0.84
# head_sent_date      0.96

# %%
#Sorted missing values visualisation .
def plot_missing_values(missing_values):
    plt.figure(figsize=(20 , 10))
    sns.set(style="whitegrid", color_codes=True)
    sns.barplot(x = missing_values.index, y = 'count', data=missing_values)
    plt.xticks(rotation = 55)
    plt.show()

# %%
plot_missing_values(missing_values)

# %%
#Ho wmany total of missing values do we have ?
total_cells = np.product(Data.shape)
total_missing = missing_values.sum()

#Percent of missing values in dataset
percent_missing = (total_missing/total_cells)
print("Percent of missing values in dataset : ",percent_missing)
# Out:
# Percent of missing values in dataset :  count    0.000056
# dtype: float64

# %%
print("- numerical values:\n",Numerical_val)
print("\n- categorical values:\n",categorical_val)
Data.head(15)
Data.shape
# Out:
# - numerical values:
#  Index(['vaccination_yrs', 'vaccination_date', 'quarantine_date',
#        'release_date'],
#       dtype='object')
#
# - categorical values:
#  Index(['bite_date', 'SpeciesIDDesc', 'BreedIDDesc', 'GenderIDDesc', 'color',
#        'victim_zip', 'AdvIssuedYNDesc', 'WhereBittenIDDesc',
#        'DispositionIDDesc', 'head_sent_date', 'ResultsIDDesc'],
#       dtype='object')
# (8954, 15)

# %%
#Rename some values
Data['GenderIDDesc'] = Data['GenderIDDesc'].map({'FEMALE': 'F', 'MALE': 'M'})

Data['AdvIssuedYNDesc'] = Data['AdvIssuedYNDesc'].fillna(Data['AdvIssuedYNDesc'].mode())
Data['ResultsIDDesc'] = Data['ResultsIDDesc'].fillna(Data['ResultsIDDesc'].mode())


Data.shape
# Out:
# (8954, 15)

# %%
Data.head()
# Out:
#              bite_date SpeciesIDDesc BreedIDDesc GenderIDDesc       color  \
# 0  1985-05-05 00:00:00           DOG         NaN            F  LIG. BROWN
# 1  1986-02-12 00:00:00           DOG         NaN          NaN   BRO & BLA
# 2  1987-05-07 00:00:00           DOG         NaN          NaN         NaN
# 3  1988-10-02 00:00:00           DOG         NaN            M   BLA & BRO
# 4  1989-08-29 00:00:00           DOG         NaN            F     BLK-WHT
#
#    vaccination_yrs vaccination_date victim_zip AdvIssuedYNDesc  \
# 0              1.0       1985-06-20      40229              NO
# 1              NaN              NaT      40218              NO
# 2              NaN              NaT      40219              NO
# 3              NaN              NaT        NaN              NO
# 4              NaN              NaT        NaN              NO
#
#   WhereBittenIDDesc quarantine_date DispositionIDDesc head_sent_date  \
# 0              BODY      1985-05-05           UNKNOWN            NaN
# 1              BODY      1986-02-12           UNKNOWN            NaN
# 2              BODY      1990-05-07           UNKNOWN            NaN
# 3              BODY      1990-10-02           UNKNOWN            NaN
# 4              BODY             NaT           UNKNOWN            NaN
#
#   release_date ResultsIDDesc
# 0          NaT       UNKNOWN
# 1          NaT       UNKNOWN
# 2          NaT       UNKNOWN
# 3          NaT       UNKNOWN
# 4          NaT       UNKNOWN

# %%
#Handler some NaN values
Data['vaccination_yrs'].fillna(value=Data['vaccination_yrs'].mean(), inplace=True)
Data['GenderIDDesc'] = Data['GenderIDDesc'].fillna(Data['GenderIDDesc'].mode()[0]) #Replace NaN values by Gender mode 
Data['BreedIDDesc'] = Data['BreedIDDesc'].fillna(Data['BreedIDDesc'].mode()[0]) #Replace NaN values by BreedIDDesc mode 
Data['WhereBittenIDDesc'] = Data['WhereBittenIDDesc'].fillna(Data['WhereBittenIDDesc'].mode()[0]) #Replace NaN values by WhereBittenIDDesc mode 
Data['DispositionIDDesc'] = Data['DispositionIDDesc'].fillna(Data['DispositionIDDesc'].mode()[0]) #Replace NaN values by DispositionIDDesc mode 
Data['color'] = Data['color'].fillna(Data['color'].mode()[0]) #Replace NaN values by color's mode 
Data['victim_zip'] = Data['victim_zip'].fillna(Data['victim_zip'].mode()[0])
Data['vaccination_date'] = Data['vaccination_date'].fillna(Data['vaccination_date'].mode()[0])
Data['quarantine_date'] = Data['quarantine_date'].fillna(Data['quarantine_date'].mode()[0])
Data['release_date'] = Data['release_date'].fillna(Data['release_date'].mode()[0])
Data['head_sent_date'] = Data['head_sent_date'].fillna(Data['head_sent_date'].mode()[0])
Data['bite_date'] = Data['bite_date'].fillna(Data['bite_date'].mode()[0])
Data['SpeciesIDDesc'] = Data['SpeciesIDDesc'].fillna(Data['SpeciesIDDesc'].mode()[0])
   
Data.head(60)
# Out:
#               bite_date SpeciesIDDesc BreedIDDesc GenderIDDesc       color  \
# 0   1985-05-05 00:00:00           DOG    PIT BULL            F  LIG. BROWN
# 1   1986-02-12 00:00:00           DOG    PIT BULL            M   BRO & BLA
# 2   1987-05-07 00:00:00           DOG    PIT BULL            M       BLACK
# 3   1988-10-02 00:00:00           DOG    PIT BULL            M   BLA & BRO
# 4   1989-08-29 00:00:00           DOG    PIT BULL            F     BLK-WHT
# 5   1989-11-24 00:00:00           DOG    PIT BULL            M       BLACK
# 6   1990-02-08 00:00:00           DOG    PIT BULL            F  BLACK/WHIT
# 7   1990-02-22 00:00:00           DOG    PIT BULL            M     BLK-WHT
# 8   1990-08-02 00:00:00           DOG    PIT BULL            M       BROWN
# 9   1990-08-19 00:00:00           DOG    PIT BULL            M     BRN-TAN
# 10  1990-08-31 00:00:00           DOG    PIT BULL            M         TRI
# 11  1990-10-20 00:00:00           DOG    PIT BULL            M         BLK
# 12  1991-02-09 00:00:00           DOG    PIT BULL            M     BLK-BRN
# 13  1991-07-05 00:00:00           DOG    PIT BULL            M     BLK-BRN
# 14  1991-09-14 00:00:00           DOG    PIT BULL            M         WHT
# 15  1991-10-09 00:00:00           DOG    PIT BULL            F     WHT-BRN
# 16  1991-11-07 00:00:00           DOG    PIT BULL            M       BLACK
# 17  1992-02-08 00:00:00           DOG    PIT BULL            M         BLK
# 18  1992-02-27 00:00:00           DOG    PIT BULL            M     BLK-TAN
# 19  1992-03-06 00:00:00           DOG    PIT BULL            M         WHT
# 20  1992-03-18 00:00:00           CAT    PIT BULL            M       BLACK
# 21  1992-04-06 00:00:00           DOG    PIT BULL            M         BLK
# 22  1992-05-06 00:00:00           DOG    PIT BULL            M         BLK
# 23  1992-06-04 00:00:00           DOG    PIT BULL            M         BRN
# 24  1992-06-29 00:00:00           DOG    PIT BULL            F         RED
# 25  1992-08-06 00:00:00           DOG    PIT BULL            M       WHITE
# 26  1992-08-26 00:00:00           DOG    PIT BULL            M     BRN-BLK
# 27  1993-04-04 00:00:00           DOG    PIT BULL            M       BLACK
# 28  1993-04-06 00:00:00           CAT    PIT BULL            M       BLACK
# 29  1993-05-12 00:00:00           DOG    PIT BULL            M         BRN
# 30  1993-06-20 00:00:00           DOG    PIT BULL            M       BLACK
# 31  1993-07-09 00:00:00           DOG    PIT BULL            F         BRN
# 32  1993-12-04 00:00:00           DOG    PIT BULL            M       BLACK
# 33  1994-03-31 00:00:00           DOG    PIT BULL            M     BRN-BLK
# 34  1994-04-11 00:00:00           DOG    PIT BULL            M         BLK
# 35  1994-05-08 00:00:00           DOG    PIT BULL            M       BLACK
# 36  1994-05-10 00:00:00           DOG    PIT BULL            F  MULT COLOR
# 37  1994-05-22 00:00:00           DOG    PIT BULL            M         TRI
# 38  1994-06-10 00:00:00           DOG    PIT BULL            M       BLACK
# 39  1994-07-21 00:00:00           DOG    PIT BULL            M       BLACK
# 40  2009-10-29 00:00:00           CAT    PIT BULL            F        GRAY
# 41  2009-12-02 00:00:00           DOG    PIT BULL            M     TAN-BRN
# 42  2009-12-11 00:00:00           DOG    PIT BULL            M     BLK-BRN
# 43  2009-12-21 00:00:00           DOG    PIT BULL            M       BLACK
# 44  2009-12-24 00:00:00           DOG    PIT BULL            M     BRN-WHT
# 45  2009-12-24 00:00:00           DOG    PIT BULL            M       BLACK
# 46  2009-12-28 00:00:00           DOG    PIT BULL            M       BLACK
# 47  2009-12-29 00:00:00           DOG    PIT BULL            F     WHT-BRN
# 48  2009-12-30 00:00:00           DOG    PIT BULL            F       WHITE
# 49  2009-12-30 00:00:00           DOG    PIT BULL            M     BLK-WHT
# 50  2009-12-30 00:00:00           DOG    PIT BULL            F     BLK-WHT
# 51  2009-12-31 00:00:00           DOG    PIT BULL            M    WHT-GRAY
# 52  2009-12-31 00:00:00           CAT    PIT BULL            M       WHITE
# 53  2009-12-31 00:00:00           DOG    PIT BULL            M         BRN
# 54  2010-01-01 00:00:00           DOG    PIT BULL            F         WHT
# 55  2010-01-02 00:00:00           DOG    PIT BULL            M     BLK-BRN
# 56  2010-01-02 00:00:00           DOG    PIT BULL            M       BLACK
# 57  2010-01-02 00:00:00           CAT    PIT BULL            F       BLACK
# 58  2010-01-02 00:00:00           DOG    PIT BULL            M         BLK
# 59  2010-01-02 00:00:00           DOG    PIT BULL            F     BRN-WHT
#
#     vaccination_yrs vaccination_date victim_zip AdvIssuedYNDesc  \
# 0          1.000000       1985-06-20      40229              NO
# 1          1.452719       2015-10-01      40218              NO
# 2          1.452719       2015-10-01      40219              NO
# 3          1.452719       2015-10-01      40272              NO
# 4          1.452719       2015-10-01      40272              NO
# 5          1.452719       2015-10-01      40211              NO
# 6          1.000000       1990-02-13      40203              NO
# 7          1.452719       2015-10-01      40272              NO
# 8          1.452719       2015-10-01      40272              NO
# 9          1.452719       2015-10-01      40272              NO
# 10         1.452719       2015-10-01      40272              NO
# 11         1.452719       2015-10-01      40272              NO
# 12         1.452719       2015-10-01      40272              NO
# 13         1.452719       2015-10-01      40272             YES
# 14         1.452719       2015-10-01      40272              NO
# 15         1.452719       2015-10-01      40272              NO
# 16         1.452719       2015-10-01      40272              NO
# 17         1.452719       2015-10-01      40272              NO
# 18         1.452719       2015-10-01      40272              NO
# 19         1.452719       2015-10-01      40272              NO
# 20         1.452719       2015-10-01      40272              NO
# 21         1.452719       2015-10-01      40272              NO
# 22         1.452719       2015-10-01      40272              NO
# 23         1.452719       2015-10-01      40272              NO
# 24         1.452719       2015-10-01      40272              NO
# 25         1.452719       2015-10-01      40215              NO
# 26         1.452719       2015-10-01      40210              NO
# 27         1.452719       2015-10-01      40272              NO
# 28         1.452719       2015-10-01      40272              NO
# 29         1.452719       2015-10-01      40272              NO
# 30         1.452719       2015-10-01      40272              NO
# 31         1.452719       2015-10-01      40272             YES
# 32         1.452719       2015-10-01      40272              NO
# 33         1.452719       2015-10-01      40272              NO
# 34         1.452719       2015-10-01      40272              NO
# 35         1.452719       2015-10-01      40272              NO
# 36         1.452719       2015-10-01      40272              NO
# 37         1.452719       2015-10-01      40272              NO
# 38         1.452719       2015-10-01      40272              NO
# 39         1.452719       2015-10-01      40272              NO
# 40         1.452719       2015-10-01      40206              NO
# 41         1.000000       2010-01-16      40291              NO
# 42         1.452719       2015-10-01      40272              NO
# 43         1.452719       2015-10-01      40218              NO
# 44         1.000000       2009-04-30      40165              NO
# 45         1.452719       2015-10-01      40229              NO
# 46         1.452719       2015-10-01      40299              NO
# 47         3.000000       2008-06-07      40291              NO
# 48         3.000000       2010-01-06      40229              NO
# 49         1.452719       2015-10-01      40218              NO
# 50         1.000000       2009-12-26      40220              NO
# 51         3.000000       2008-08-28      40220              NO
# 52         1.000000       2010-01-14      40220              NO
# 53         1.000000       2009-07-23      40241              NO
# 54         1.000000       2009-10-22      40228              NO
# 55         3.000000       2008-02-07      40291              NO
# 56         1.452719       2015-10-01      40219             YES
# 57         1.452719       2015-10-01      40291              NO
# 58         1.452719       2015-10-01      40216              NO
# 59         1.000000       2010-01-27      40071              NO
#
#    WhereBittenIDDesc quarantine_date DispositionIDDesc       head_sent_date  \
# 0               BODY      1985-05-05           UNKNOWN  2010-05-21 00:00:00
# 1               BODY      1986-02-12           UNKNOWN  2010-05-21 00:00:00
# 2               BODY      1990-05-07           UNKNOWN  2010-05-21 00:00:00
# 3               BODY      1990-10-02           UNKNOWN  2010-05-21 00:00:00
# 4               BODY      2010-04-05           UNKNOWN  2010-05-21 00:00:00
# 5               BODY      2010-04-05           UNKNOWN  2010-05-21 00:00:00
# 6               BODY      1990-02-12           UNKNOWN  2010-05-21 00:00:00
# 7               BODY      1990-02-23          RELEASED  2010-05-21 00:00:00
# 8               BODY      1990-08-02           UNKNOWN  2010-05-21 00:00:00
# 9               BODY      1990-08-20          RELEASED  2010-05-21 00:00:00
# 10              HEAD      1990-09-04          RELEASED  2010-05-21 00:00:00
# 11              BODY      1990-10-22          RELEASED  2010-05-21 00:00:00
# 12              BODY      1991-02-13          RELEASED  2010-05-21 00:00:00
# 13              BODY      1991-07-09          RELEASED  2010-05-21 00:00:00
# 14              BODY      1991-09-19          RELEASED  2010-05-21 00:00:00
# 15              HEAD      1991-10-11          RELEASED  2010-05-21 00:00:00
# 16              BODY      1991-11-14          RELEASED  2010-05-21 00:00:00
# 17              BODY      1992-02-12           UNKNOWN  2010-05-21 00:00:00
# 18              BODY      1992-03-02          RELEASED  2010-05-21 00:00:00
# 19              BODY      1992-03-11          RELEASED  2010-05-21 00:00:00
# 20              HEAD      1992-03-24          RELEASED  2010-05-21 00:00:00
# 21              BODY      1992-04-08          RELEASED  2010-05-21 00:00:00
# 22              BODY      1992-05-09          RELEASED  2010-05-21 00:00:00
# 23              BODY      1992-06-10          RELEASED  2010-05-21 00:00:00
# 24              BODY      1992-06-30          RELEASED  2010-05-21 00:00:00
# 25              BODY      1992-08-06          RELEASED  2010-05-21 00:00:00
# 26              BODY      1992-08-31          RELEASED  2010-05-21 00:00:00
# 27              BODY      1993-04-05          RELEASED  2010-05-21 00:00:00
# 28              BODY      1993-04-19          RELEASED  2010-05-21 00:00:00
# 29              HEAD      1993-05-14          RELEASED  2010-05-21 00:00:00
# 30              BODY      1993-06-21          RELEASED  2010-05-21 00:00:00
# 31              BODY      1993-07-09          RELEASED  2010-05-21 00:00:00
# 32              BODY      1993-12-06          RELEASED  2010-05-21 00:00:00
# 33              BODY      1994-04-06          RELEASED  2010-05-21 00:00:00
# 34              BODY      1994-04-13          RELEASED  2010-05-21 00:00:00
# 35              BODY      1994-05-09          RELEASED  2010-05-21 00:00:00
# 36              HEAD      1994-05-13          RELEASED  2010-05-21 00:00:00
# 37              BODY      1994-05-24          RELEASED  2010-05-21 00:00:00
# 38              BODY      1994-06-15          RELEASED  2010-05-21 00:00:00
# 39              BODY      1994-07-21          RELEASED  2010-05-21 00:00:00
# 40              BODY      2009-10-30           UNKNOWN  2010-05-21 00:00:00
# 41              BODY      2009-12-03          RELEASED  2010-05-21 00:00:00
# 42              BODY      2009-12-11          RELEASED  2010-05-21 00:00:00
# 43              HEAD      2009-12-29           UNKNOWN  2010-05-21 00:00:00
# 44              HEAD      2009-12-28          RELEASED  2010-05-21 00:00:00
# 45              BODY      2009-12-29           UNKNOWN  2010-05-21 00:00:00
# 46              HEAD      2009-12-29           UNKNOWN  2010-05-21 00:00:00
# 47              BODY      2009-12-30          RELEASED  2010-05-21 00:00:00
# 48              BODY      2009-12-31          RELEASED  2010-05-21 00:00:00
# 49              BODY      2010-01-06          RELEASED  2010-05-21 00:00:00
# 50              BODY      2010-01-06           UNKNOWN  2010-05-21 00:00:00
# 51              BODY      2010-01-04          RELEASED  2010-05-21 00:00:00
# 52              BODY      2010-01-04          RELEASED  2010-05-21 00:00:00
# 53              BODY      2010-01-04          RELEASED  2010-05-21 00:00:00
# 54              BODY      2010-01-04          RELEASED  2010-05-21 00:00:00
# 55              HEAD      2010-01-04          RELEASED  2010-05-21 00:00:00
# 56              BODY      2010-01-04           UNKNOWN  2010-05-21 00:00:00
# 57              BODY      2010-01-04          RELEASED  2010-05-21 00:00:00
# 58              BODY      2010-01-04           UNKNOWN  2010-05-21 00:00:00
# 59              HEAD      2010-01-06          RELEASED  2010-05-21 00:00:00
#
#    release_date ResultsIDDesc
# 0    2016-07-05       UNKNOWN
# 1    2016-07-05       UNKNOWN
# 2    2016-07-05       UNKNOWN
# 3    2016-07-05       UNKNOWN
# 4    2016-07-05       UNKNOWN
# 5    2016-07-05       UNKNOWN
# 6    2016-07-05       UNKNOWN
# 7    2016-07-05       UNKNOWN
# 8    2016-07-05       UNKNOWN
# 9    2016-07-05       UNKNOWN
# 10   2016-07-05       UNKNOWN
# 11   2016-07-05       UNKNOWN
# 12   2016-07-05       UNKNOWN
# 13   2016-07-05       UNKNOWN
# 14   2016-07-05       UNKNOWN
# 15   2016-07-05       UNKNOWN
# 16   2016-07-05       UNKNOWN
# 17   2016-07-05       UNKNOWN
# 18   2016-07-05       UNKNOWN
# 19   2016-07-05       UNKNOWN
# 20   2016-07-05       UNKNOWN
# 21   2016-07-05       UNKNOWN
# 22   2016-07-05       UNKNOWN
# 23   2016-07-05       UNKNOWN
# 24   2016-07-05       UNKNOWN
# 25   2016-07-05       UNKNOWN
# 26   2016-07-05       UNKNOWN
# 27   2016-07-05       UNKNOWN
# 28   2016-07-05       UNKNOWN
# 29   2016-07-05       UNKNOWN
# 30   2016-07-05       UNKNOWN
# 31   2016-07-05       UNKNOWN
# 32   2016-07-05       UNKNOWN
# 33   2016-07-05       UNKNOWN
# 34   2016-07-05       UNKNOWN
# 35   2016-07-05       UNKNOWN
# 36   2016-07-05       UNKNOWN
# 37   2016-07-05       UNKNOWN
# 38   2016-07-05       UNKNOWN
# 39   2016-07-05       UNKNOWN
# 40   2016-07-05       UNKNOWN
# 41   2016-07-05       UNKNOWN
# 42   2016-07-05       UNKNOWN
# 43   2016-07-05       UNKNOWN
# 44   2016-07-05       UNKNOWN
# 45   2016-07-05       UNKNOWN
# 46   2016-07-05       UNKNOWN
# 47   2016-07-05       UNKNOWN
# 48   2016-07-05       UNKNOWN
# 49   2016-07-05       UNKNOWN
# 50   2016-07-05       UNKNOWN
# 51   2016-07-05       UNKNOWN
# 52   2016-07-05       UNKNOWN
# 53   2016-07-05       UNKNOWN
# 54   2016-07-05       UNKNOWN
# 55   2016-07-05       UNKNOWN
# 56   2016-07-05       UNKNOWN
# 57   2016-07-05       UNKNOWN
# 58   2016-07-05       UNKNOWN
# 59   2016-07-05       UNKNOWN

# %%
Data.shape
# Out:
# (8954, 15)

# %%
count_na_rows()
# Out:
# bite_date               0
# SpeciesIDDesc           0
# BreedIDDesc             0
# GenderIDDesc            0
# color                   0
# vaccination_yrs         0
# vaccination_date        0
# victim_zip              0
# AdvIssuedYNDesc      6394
# WhereBittenIDDesc       0
# quarantine_date         0
# DispositionIDDesc       0
# head_sent_date          0
# release_date            0
# ResultsIDDesc        7413
# dtype: int64
#
# Data shape: (8954, 15)

# %%
#Rename columns 
Data = Data.rename(columns=
                      {
                          'bite_date':'bite date',
                          'vaccination_yrs':'vaccination year',
                          'vaccination_date':'vaccination date',
                          'quarantine_date':'quarantine date',
                          'head_sent_date':'head sent date',
                          'release_date':'release date',
                          'victim_zip':'victim zip'
                          
                      })

# %%
#Change in uppercase
Data['BreedIDDesc'] = Data['BreedIDDesc'].str.upper()
Data['WhereBittenIDDesc'] = Data['WhereBittenIDDesc'].str.upper()
Data['DispositionIDDesc'] = Data['DispositionIDDesc'].str.upper()
Data['head sent date'] = Data['head sent date'].str.upper()
Data['victim zip'] = Data['victim zip'].str.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [30], in <cell line: 6>()
#       4 Data['DispositionIDDesc'] = Data['DispositionIDDesc'].str.upper()
#       5 Data['head sent date'] = Data['head sent date'].str.upper()
# ----> 6 Data['victim zip'] = Data['quarantine date'].str.upper()
#
# File ~\Anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# File ~\Anaconda3\lib\site-packages\pandas\core\accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# --> 182 accessor_obj = self._accessor(obj)
#     183 # Replace the property with the accessor object. Inspired by:
#     184 # https://www.pydanny.com/cached-property.html
#     185 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     186 # NDFrame
#     187 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~\Anaconda3\lib\site-packages\pandas\core\strings\accessor.py:177, in StringMethods.__init__(self, data)
#     174 def __init__(self, data):
#     175     from pandas.core.arrays.string_ import StringDtype
# --> 177     self._inferred_dtype = self._validate(data)
#     178     self._is_categorical = is_categorical_dtype(data.dtype)
#     179     self._is_string = isinstance(data.dtype, StringDtype)
#
# File ~\Anaconda3\lib\site-packages\pandas\core\strings\accessor.py:231, in StringMethods._validate(data)
#     228 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     230 if inferred_dtype not in allowed_types:
# --> 231     raise AttributeError("Can only use .str accessor with string values!")
#     232 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
outPut_data = pd.DataFrame(Data)
output_data = outPut_data.to_csv("output_data.csv",)
output_data

# %%
Data.head(15)

# %%
count_na_rows()

# %%
msno.matrix(Data)

# %%
Data.shape

# %% [markdown]
# 1. Which animals are most likely to bite humans?
#
# 2. Are some dog breeds more likely to bite?
#
# 3. What factors are most strongly associated with a positive rabies ID?

# %%
#Which animals are most likely to bite humans?

animal_likely_to_bite = Data['SpeciesIDDesc'].value_counts()
print("\nAnimals most likely to bite humans:\n\n",animal_likely_to_bite)

animal_likely_to_bite.plot.barh(figsize=(15, 10), color=['red','green','orange','blue']) # TBD Visualize real value bar cross to estimate values bar

# %%
#2. Are some dog breeds more likely to bite?

Data_DOGS = Data[Data['SpeciesIDDesc'] =='DOG']
Dogs_breed_more_likely = Data_DOGS['BreedIDDesc'].value_counts()  
top_Dogs_breed_more_likely= Dogs_breed_more_likely.head(10)

print("\nDogs breed more likely: ",Data['SpeciesIDDesc'].mode()[0])
print("\n\nTop 10 dogs breed more likely:\n",top_Dogs_breed_more_likely)

top_Dogs_breed_more_likely.plot.barh(figsize=(15, 10) ,
                                     color=['red','green','orange','blue' , 'cyan','gray','purple','teal','magenta','yellow'])

# %%
#3. What factors are most strongly associated with a positive rabies ID?

categorical_features=identify_nominal_columns(Data)
categorical_features

associations(Data, 
             nominal_columns='auto', 
             numerical_columns=None, 
             mark_columns=False,
             nom_nom_assoc='cramer', 
             num_num_assoc='pearson', 
             #bias_correction=True, 
            # nan_strategy=_REPLACE, 
            # nan_replace_value=_DEFAULT_REPLACE_VALUE, 
             ax=None, figsize=None, 
             annot=True, fmt='.2f', 
             cmap=None, sv_color='silver', 
             cbar=True, vmax=1.0, 
             vmin=None, plot=True, 
             compute_only=False, 
             clustering=False, 
             title=None,
             filename=None)

df_complete_corr= associations(Data, filename= 'complete_correlation.png', figsize=(15,10))

df_complete_corr.dropna(axis=1, how='all').dropna(axis=0, how='all').style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
